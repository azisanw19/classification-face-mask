# %%
import numpy as np
import glob
import cv2
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from skimage.filters import sobel

SIZE = 128

# %%
train_img = []
train_label = [] 
for dir_path in glob.glob("Dataset/train/*"):
    label = dir_path.split("/")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(dir_path, "*.jpg")):
        print(img_path)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        train_img.append(img)
        train_label.append(label)
        
train_img = np.array(train_img)
train_label = np.array(train_label)
# Out:
# with_mask
# Dataset/train/with_mask/with_mask (94).jpg
# Dataset/train/with_mask/with_mask (332).jpg
# Dataset/train/with_mask/with_mask (123).jpg
# Dataset/train/with_mask/with_mask (20).jpg
# Dataset/train/with_mask/with_mask (360).jpg
# Dataset/train/with_mask/with_mask (339).jpg
# Dataset/train/with_mask/with_mask (372).jpg
# Dataset/train/with_mask/with_mask (232).jpg
# Dataset/train/with_mask/with_mask (335).jpg
# Dataset/train/with_mask/with_mask (308).jpg
# Dataset/train/with_mask/with_mask (91).jpg
# Dataset/train/with_mask/with_mask (273).jpg
# Dataset/train/with_mask/with_mask (189).jpg
# Dataset/train/with_mask/with_mask (113).jpg
# Dataset/train/with_mask/with_mask (28).jpg
# Dataset/train/with_mask/with_mask (336).jpg
# Dataset/train/with_mask/with_mask (236).jpg
# Dataset/train/with_mask/with_mask (221).jpg
# Dataset/train/with_mask/with_mask (380).jpg
# Dataset/train/with_mask/with_mask (385).jpg
# Dataset/train/with_mask/with_mask (112).jpg
# Dataset/train/with_mask/with_mask (153).jpg
# Dataset/train/with_mask/with_mask (213).jpg
# Dataset/train/with_mask/with_mask (390).jpg
# Dataset/train/with_mask/with_mask (158).jpg
# Dataset/train/with_mask/with_mask (130).jpg
# Dataset/train/with_mask/with_mask (243).jpg
# Dataset/train/with_mask/with_mask (260).jpg
# Dataset/train/with_mask/with_mask (177).jpg
# Dataset/train/with_mask/with_mask (195).jpg
# Dataset/train/with_mask/with_mask (293).jpg
# Dataset/train/with_mask/with_mask (344).jpg
# Dataset/train/with_mask/with_mask (230).jpg
# Dataset/train/with_mask/with_mask (368).jpg
# Dataset/train/with_mask/with_mask (374).jpg
# Dataset/train/with_mask/with_mask (281).jpg
# Dataset/train/with_mask/with_mask (115).jpg
# Dataset/train/with_mask/with_mask (180).jpg
# Dataset/train/with_mask/with_mask (8).jpg
# Dataset/train/with_mask/with_mask (399).jpg
# Dataset/train/with_mask/with_mask (62).jpg
# Dataset/train/with_mask/with_mask (140).jpg
# Dataset/train/with_mask/with_mask (100).jpg
# Dataset/train/with_mask/with_mask (197).jpg
# Dataset/train/with_mask/with_mask (79).jpg
# Dataset/train/with_mask/with_mask (186).jpg
# Dataset/train/with_mask/with_mask (297).jpg
# Dataset/train/with_mask/with_mask (110).jpg
# Dataset/train/with_mask/with_mask (387).jpg
# Dataset/train/with_mask/with_mask (13).jpg
# Dataset/train/with_mask/with_mask (377).jpg
# Dataset/train/with_mask/with_mask (337).jpg
# Dataset/train/with_mask/with_mask (203).jpg
# Dataset/train/with_mask/with_mask (18).jpg
# Dataset/train/with_mask/with_mask (67).jpg
# Dataset/train/with_mask/with_mask (199).jpg
# Dataset/train/with_mask/with_mask (314).jpg
# Dataset/train/with_mask/with_mask (118).jpg
# Dataset/train/with_mask/with_mask (1).jpg
# Dataset/train/with_mask/with_mask (322).jpg
# Dataset/train/with_mask/with_mask (161).jpg
# Dataset/train/with_mask/with_mask (317).jpg
# Dataset/train/with_mask/with_mask (192).jpg
# Dataset/train/with_mask/with_mask (267).jpg
# Dataset/train/with_mask/with_mask (216).jpg
# Dataset/train/with_mask/with_mask (148).jpg
# Dataset/train/with_mask/with_mask (395).jpg
# Dataset/train/with_mask/with_mask (257).jpg
# Dataset/train/with_mask/with_mask (389).jpg
# Dataset/train/with_mask/with_mask (358).jpg
# Dataset/train/with_mask/with_mask (11).jpg
# Dataset/train/with_mask/with_mask (255).jpg
# Dataset/train/with_mask/with_mask (296).jpg
# Dataset/train/with_mask/with_mask (61).jpg
# Dataset/train/with_mask/with_mask (231).jpg
# Dataset/train/with_mask/with_mask (266).jpg
# Dataset/train/with_mask/with_mask (35).jpg
# Dataset/train/with_mask/with_mask (309).jpg
# Dataset/train/with_mask/with_mask (394).jpg
# Dataset/train/with_mask/with_mask (87).jpg
# Dataset/train/with_mask/with_mask (178).jpg
# Dataset/train/with_mask/with_mask (244).jpg
# Dataset/train/with_mask/with_mask (298).jpg
# Dataset/train/with_mask/with_mask (175).jpg
# Dataset/train/with_mask/with_mask (313).jpg
# Dataset/train/with_mask/with_mask (376).jpg
# Dataset/train/with_mask/with_mask (104).jpg
# Dataset/train/with_mask/with_mask (367).jpg
# Dataset/train/with_mask/with_mask (105).jpg
# Dataset/train/with_mask/with_mask (170).jpg
# Dataset/train/with_mask/with_mask (142).jpg
# Dataset/train/with_mask/with_mask (346).jpg
# Dataset/train/with_mask/with_mask (252).jpg
# Dataset/train/with_mask/with_mask (57).jpg
# Dataset/train/with_mask/with_mask (60).jpg
# Dataset/train/with_mask/with_mask (359).jpg
# Dataset/train/with_mask/with_mask (304).jpg
# Dataset/train/with_mask/with_mask (120).jpg
# Dataset/train/with_mask/with_mask (323).jpg
# Dataset/train/with_mask/with_mask (73).jpg
# Dataset/train/with_mask/with_mask (253).jpg
# Dataset/train/with_mask/with_mask (392).jpg
# Dataset/train/with_mask/with_mask (135).jpg
# Dataset/train/with_mask/with_mask (6).jpg
# Dataset/train/with_mask/with_mask (22).jpg
# Dataset/train/with_mask/with_mask (81).jpg
# Dataset/train/with_mask/with_mask (383).jpg
# Dataset/train/with_mask/with_mask (154).jpg
# Dataset/train/with_mask/with_mask (205).jpg
# Dataset/train/with_mask/with_mask (338).jpg
# Dataset/train/with_mask/with_mask (396).jpg
# Dataset/train/with_mask/with_mask (85).jpg
# Dataset/train/with_mask/with_mask (194).jpg
# Dataset/train/with_mask/with_mask (228).jpg
# Dataset/train/with_mask/with_mask (294).jpg
# Dataset/train/with_mask/with_mask (247).jpg
# Dataset/train/with_mask/with_mask (108).jpg
# Dataset/train/with_mask/with_mask (276).jpg
# Dataset/train/with_mask/with_mask (333).jpg
# Dataset/train/with_mask/with_mask (74).jpg
# Dataset/train/with_mask/with_mask (220).jpg
# Dataset/train/with_mask/with_mask (30).jpg
# Dataset/train/with_mask/with_mask (179).jpg
# Dataset/train/with_mask/with_mask (201).jpg
# Dataset/train/with_mask/with_mask (206).jpg
# Dataset/train/with_mask/with_mask (210).jpg
# Dataset/train/with_mask/with_mask (124).jpg
# Dataset/train/with_mask/with_mask (109).jpg
# Dataset/train/with_mask/with_mask (303).jpg
# Dataset/train/with_mask/with_mask (284).jpg
# Dataset/train/with_mask/with_mask (365).jpg
# Dataset/train/with_mask/with_mask (116).jpg
# Dataset/train/with_mask/with_mask (325).jpg
# Dataset/train/with_mask/with_mask (366).jpg
# Dataset/train/with_mask/with_mask (271).jpg
# Dataset/train/with_mask/with_mask (295).jpg
# Dataset/train/with_mask/with_mask (40).jpg
# Dataset/train/with_mask/with_mask (305).jpg
# Dataset/train/with_mask/with_mask (316).jpg
# Dataset/train/with_mask/with_mask (373).jpg
# Dataset/train/with_mask/with_mask (47).jpg
# Dataset/train/with_mask/with_mask (76).jpg
# Dataset/train/with_mask/with_mask (258).jpg
# Dataset/train/with_mask/with_mask (101).jpg
# Dataset/train/with_mask/with_mask (263).jpg
# Dataset/train/with_mask/with_mask (167).jpg
# Dataset/train/with_mask/with_mask (324).jpg
# Dataset/train/with_mask/with_mask (149).jpg
# Dataset/train/with_mask/with_mask (155).jpg
# Dataset/train/with_mask/with_mask (111).jpg
# Dataset/train/with_mask/with_mask (181).jpg
# Dataset/train/with_mask/with_mask (211).jpg
# Dataset/train/with_mask/with_mask (34).jpg
# Dataset/train/with_mask/with_mask (83).jpg
# Dataset/train/with_mask/with_mask (98).jpg
# Dataset/train/with_mask/with_mask (289).jpg
# Dataset/train/with_mask/with_mask (353).jpg
# Dataset/train/with_mask/with_mask (69).jpg
# Dataset/train/with_mask/with_mask (240).jpg
# Dataset/train/with_mask/with_mask (134).jpg
# Dataset/train/with_mask/with_mask (217).jpg
# Dataset/train/with_mask/with_mask (137).jpg
# Dataset/train/with_mask/with_mask (49).jpg
# Dataset/train/with_mask/with_mask (97).jpg
# Dataset/train/with_mask/with_mask (356).jpg
# Dataset/train/with_mask/with_mask (95).jpg
# Dataset/train/with_mask/with_mask (92).jpg
# Dataset/train/with_mask/with_mask (384).jpg
# Dataset/train/with_mask/with_mask (2).jpg
# Dataset/train/with_mask/with_mask (282).jpg
# Dataset/train/with_mask/with_mask (132).jpg
# Dataset/train/with_mask/with_mask (279).jpg
# Dataset/train/with_mask/with_mask (320).jpg
# Dataset/train/with_mask/with_mask (190).jpg
# Dataset/train/with_mask/with_mask (129).jpg
# Dataset/train/with_mask/with_mask (200).jpg
# Dataset/train/with_mask/with_mask (361).jpg
# Dataset/train/with_mask/with_mask (151).jpg
# Dataset/train/with_mask/with_mask (300).jpg
# Dataset/train/with_mask/with_mask (65).jpg
# Dataset/train/with_mask/with_mask (234).jpg
# Dataset/train/with_mask/with_mask (286).jpg
# Dataset/train/with_mask/with_mask (45).jpg
# Dataset/train/with_mask/with_mask (354).jpg
# Dataset/train/with_mask/with_mask (141).jpg
# Dataset/train/with_mask/with_mask (33).jpg
# Dataset/train/with_mask/with_mask (51).jpg
# Dataset/train/with_mask/with_mask (169).jpg
# Dataset/train/with_mask/with_mask (17).jpg
# Dataset/train/with_mask/with_mask (254).jpg
# Dataset/train/with_mask/with_mask (302).jpg
# Dataset/train/with_mask/with_mask (202).jpg
# Dataset/train/with_mask/with_mask (274).jpg
# Dataset/train/with_mask/with_mask (270).jpg
# Dataset/train/with_mask/with_mask (371).jpg
# Dataset/train/with_mask/with_mask (25).jpg
# Dataset/train/with_mask/with_mask (278).jpg
# Dataset/train/with_mask/with_mask (330).jpg
# Dataset/train/with_mask/with_mask (246).jpg
# Dataset/train/with_mask/with_mask (363).jpg
# Dataset/train/with_mask/with_mask (15).jpg
# Dataset/train/with_mask/with_mask (237).jpg
# Dataset/train/with_mask/with_mask (364).jpg
# Dataset/train/with_mask/with_mask (208).jpg
# Dataset/train/with_mask/with_mask (164).jpg
# Dataset/train/with_mask/with_mask (14).jpg
# Dataset/train/with_mask/with_mask (168).jpg
# Dataset/train/with_mask/with_mask (382).jpg
# Dataset/train/with_mask/with_mask (269).jpg
# Dataset/train/with_mask/with_mask (72).jpg
# Dataset/train/with_mask/with_mask (362).jpg
# Dataset/train/with_mask/with_mask (32).jpg
# Dataset/train/with_mask/with_mask (58).jpg
# Dataset/train/with_mask/with_mask (251).jpg
# Dataset/train/with_mask/with_mask (21).jpg
# Dataset/train/with_mask/with_mask (144).jpg
# Dataset/train/with_mask/with_mask (66).jpg
# Dataset/train/with_mask/with_mask (370).jpg
# Dataset/train/with_mask/with_mask (261).jpg
# Dataset/train/with_mask/with_mask (163).jpg
# Dataset/train/with_mask/with_mask (26).jpg
# Dataset/train/with_mask/with_mask (327).jpg
# Dataset/train/with_mask/with_mask (227).jpg
# Dataset/train/with_mask/with_mask (176).jpg
# Dataset/train/with_mask/with_mask (75).jpg
# Dataset/train/with_mask/with_mask (319).jpg
# Dataset/train/with_mask/with_mask (48).jpg
# Dataset/train/with_mask/with_mask (102).jpg
# Dataset/train/with_mask/with_mask (184).jpg
# Dataset/train/with_mask/with_mask (27).jpg
# Dataset/train/with_mask/with_mask (128).jpg
# Dataset/train/with_mask/with_mask (39).jpg
# Dataset/train/with_mask/with_mask (235).jpg
# Dataset/train/with_mask/with_mask (131).jpg
# Dataset/train/with_mask/with_mask (53).jpg
# Dataset/train/with_mask/with_mask (259).jpg
# Dataset/train/with_mask/with_mask (5).jpg
# Dataset/train/with_mask/with_mask (351).jpg
# Dataset/train/with_mask/with_mask (71).jpg
# Dataset/train/with_mask/with_mask (292).jpg
# Dataset/train/with_mask/with_mask (37).jpg
# Dataset/train/with_mask/with_mask (242).jpg
# Dataset/train/with_mask/with_mask (29).jpg
# Dataset/train/with_mask/with_mask (70).jpg
# Dataset/train/with_mask/with_mask (393).jpg
# Dataset/train/with_mask/with_mask (245).jpg
# Dataset/train/with_mask/with_mask (56).jpg
# Dataset/train/with_mask/with_mask (369).jpg
# Dataset/train/with_mask/with_mask (352).jpg
# Dataset/train/with_mask/with_mask (328).jpg
# Dataset/train/with_mask/with_mask (207).jpg
# Dataset/train/with_mask/with_mask (357).jpg
# Dataset/train/with_mask/with_mask (55).jpg
# Dataset/train/with_mask/with_mask (185).jpg
# Dataset/train/with_mask/with_mask (36).jpg
# Dataset/train/with_mask/with_mask (107).jpg
# Dataset/train/with_mask/with_mask (310).jpg
# Dataset/train/with_mask/with_mask (214).jpg
# Dataset/train/with_mask/with_mask (93).jpg
# Dataset/train/with_mask/with_mask (229).jpg
# Dataset/train/with_mask/with_mask (386).jpg
# Dataset/train/with_mask/with_mask (150).jpg
# Dataset/train/with_mask/with_mask (204).jpg
# Dataset/train/with_mask/with_mask (165).jpg
# Dataset/train/with_mask/with_mask (103).jpg
# Dataset/train/with_mask/with_mask (381).jpg
# Dataset/train/with_mask/with_mask (54).jpg
# Dataset/train/with_mask/with_mask (264).jpg
# Dataset/train/with_mask/with_mask (80).jpg
# Dataset/train/with_mask/with_mask (125).jpg
# Dataset/train/with_mask/with_mask (187).jpg
# Dataset/train/with_mask/with_mask (262).jpg
# Dataset/train/with_mask/with_mask (307).jpg
# Dataset/train/with_mask/with_mask (7).jpg
# Dataset/train/with_mask/with_mask (375).jpg
# Dataset/train/with_mask/with_mask (233).jpg
# Dataset/train/with_mask/with_mask (224).jpg
# Dataset/train/with_mask/with_mask (312).jpg
# Dataset/train/with_mask/with_mask (171).jpg
# Dataset/train/with_mask/with_mask (160).jpg
# Dataset/train/with_mask/with_mask (173).jpg
# Dataset/train/with_mask/with_mask (272).jpg
# Dataset/train/with_mask/with_mask (162).jpg
# Dataset/train/with_mask/with_mask (44).jpg
# Dataset/train/with_mask/with_mask (172).jpg
# Dataset/train/with_mask/with_mask (315).jpg
# Dataset/train/with_mask/with_mask (290).jpg
# Dataset/train/with_mask/with_mask (248).jpg
# Dataset/train/with_mask/with_mask (215).jpg
# Dataset/train/with_mask/with_mask (50).jpg
# Dataset/train/with_mask/with_mask (283).jpg
# Dataset/train/with_mask/with_mask (347).jpg
# Dataset/train/with_mask/with_mask (222).jpg
# Dataset/train/with_mask/with_mask (119).jpg
# Dataset/train/with_mask/with_mask (265).jpg
# Dataset/train/with_mask/with_mask (311).jpg
# Dataset/train/with_mask/with_mask (63).jpg
# Dataset/train/with_mask/with_mask (379).jpg
# Dataset/train/with_mask/with_mask (239).jpg
# Dataset/train/with_mask/with_mask (31).jpg
# Dataset/train/with_mask/with_mask (183).jpg
# Dataset/train/with_mask/with_mask (326).jpg
# Dataset/train/with_mask/with_mask (89).jpg
# Dataset/train/with_mask/with_mask (96).jpg
# Dataset/train/with_mask/with_mask (340).jpg
# Dataset/train/with_mask/with_mask (209).jpg
# Dataset/train/with_mask/with_mask (10).jpg
# Dataset/train/with_mask/with_mask (341).jpg
# Dataset/train/with_mask/with_mask (126).jpg
# Dataset/train/with_mask/with_mask (42).jpg
# Dataset/train/with_mask/with_mask (121).jpg
# Dataset/train/with_mask/with_mask (268).jpg
# Dataset/train/with_mask/with_mask (146).jpg
# Dataset/train/with_mask/with_mask (212).jpg
# Dataset/train/with_mask/with_mask (64).jpg
# Dataset/train/with_mask/with_mask (398).jpg
# Dataset/train/with_mask/with_mask (280).jpg
# Dataset/train/with_mask/with_mask (16).jpg
# Dataset/train/with_mask/with_mask (301).jpg
# Dataset/train/with_mask/with_mask (82).jpg
# Dataset/train/with_mask/with_mask (99).jpg
# Dataset/train/with_mask/with_mask (191).jpg
# Dataset/train/with_mask/with_mask (225).jpg
# Dataset/train/with_mask/with_mask (152).jpg
# Dataset/train/with_mask/with_mask (127).jpg
# Dataset/train/with_mask/with_mask (218).jpg
# Dataset/train/with_mask/with_mask (90).jpg
# Dataset/train/with_mask/with_mask (285).jpg
# Dataset/train/with_mask/with_mask (43).jpg
# Dataset/train/with_mask/with_mask (348).jpg
# Dataset/train/with_mask/with_mask (106).jpg
# Dataset/train/with_mask/with_mask (196).jpg
# Dataset/train/with_mask/with_mask (143).jpg
# Dataset/train/with_mask/with_mask (3).jpg
# Dataset/train/with_mask/with_mask (122).jpg
# Dataset/train/with_mask/with_mask (342).jpg
# Dataset/train/with_mask/with_mask (277).jpg
# Dataset/train/with_mask/with_mask (306).jpg
# Dataset/train/with_mask/with_mask (24).jpg
# Dataset/train/with_mask/with_mask (156).jpg
# Dataset/train/with_mask/with_mask (4).jpg
# Dataset/train/with_mask/with_mask (77).jpg
# Dataset/train/with_mask/with_mask (38).jpg
# Dataset/train/with_mask/with_mask (139).jpg
# Dataset/train/with_mask/with_mask (400).jpg
# Dataset/train/with_mask/with_mask (88).jpg
# Dataset/train/with_mask/with_mask (226).jpg
# Dataset/train/with_mask/with_mask (68).jpg
# Dataset/train/with_mask/with_mask (145).jpg
# Dataset/train/with_mask/with_mask (238).jpg
# Dataset/train/with_mask/with_mask (59).jpg
# Dataset/train/with_mask/with_mask (397).jpg
# Dataset/train/with_mask/with_mask (334).jpg
# Dataset/train/with_mask/with_mask (136).jpg
# Dataset/train/with_mask/with_mask (188).jpg
# Dataset/train/with_mask/with_mask (159).jpg
# Dataset/train/with_mask/with_mask (318).jpg
# Dataset/train/with_mask/with_mask (299).jpg
# Dataset/train/with_mask/with_mask (349).jpg
# Dataset/train/with_mask/with_mask (345).jpg
# Dataset/train/with_mask/with_mask (46).jpg
# Dataset/train/with_mask/with_mask (223).jpg
# Dataset/train/with_mask/with_mask (329).jpg
# Dataset/train/with_mask/with_mask (343).jpg
# Dataset/train/with_mask/with_mask (9).jpg
# Dataset/train/with_mask/with_mask (288).jpg
# Dataset/train/with_mask/with_mask (331).jpg
# Dataset/train/with_mask/with_mask (388).jpg
# Dataset/train/with_mask/with_mask (355).jpg
# Dataset/train/with_mask/with_mask (117).jpg
# Dataset/train/with_mask/with_mask (78).jpg
# Dataset/train/with_mask/with_mask (378).jpg
# Dataset/train/with_mask/with_mask (256).jpg
# Dataset/train/with_mask/with_mask (193).jpg
# Dataset/train/with_mask/with_mask (391).jpg
# Dataset/train/with_mask/with_mask (138).jpg
# Dataset/train/with_mask/with_mask (174).jpg
# Dataset/train/with_mask/with_mask (250).jpg
# Dataset/train/with_mask/with_mask (166).jpg
# Dataset/train/with_mask/with_mask (12).jpg
# Dataset/train/with_mask/with_mask (198).jpg
# Dataset/train/with_mask/with_mask (86).jpg
# Dataset/train/with_mask/with_mask (350).jpg
# Dataset/train/with_mask/with_mask (52).jpg
# Dataset/train/with_mask/with_mask (147).jpg
# Dataset/train/with_mask/with_mask (19).jpg
# Dataset/train/with_mask/with_mask (84).jpg
# Dataset/train/with_mask/with_mask (275).jpg
# Dataset/train/with_mask/with_mask (241).jpg
# Dataset/train/with_mask/with_mask (182).jpg
# Dataset/train/with_mask/with_mask (219).jpg
# Dataset/train/with_mask/with_mask (157).jpg
# Dataset/train/with_mask/with_mask (287).jpg
# Dataset/train/with_mask/with_mask (291).jpg
# Dataset/train/with_mask/with_mask (321).jpg
# Dataset/train/with_mask/with_mask (249).jpg
# Dataset/train/with_mask/with_mask (23).jpg
# Dataset/train/with_mask/with_mask (114).jpg
# Dataset/train/with_mask/with_mask (133).jpg
# Dataset/train/with_mask/with_mask (41).jpg
# without_mask
# Dataset/train/without_mask/without_mask (5).jpg
# Dataset/train/without_mask/without_mask (68).jpg
# Dataset/train/without_mask/without_mask (108).jpg
# Dataset/train/without_mask/without_mask (207).jpg
# Dataset/train/without_mask/without_mask (140).jpg
# Dataset/train/without_mask/without_mask (79).jpg
# Dataset/train/without_mask/without_mask (97).jpg
# Dataset/train/without_mask/without_mask (19).jpg
# Dataset/train/without_mask/without_mask (186).jpg
# Dataset/train/without_mask/without_mask (112).jpg
# Dataset/train/without_mask/without_mask (75).jpg
# Dataset/train/without_mask/without_mask (8).jpg
# Dataset/train/without_mask/without_mask (28).jpg
# Dataset/train/without_mask/without_mask (89).jpg
# Dataset/train/without_mask/without_mask (147).jpg
# Dataset/train/without_mask/without_mask (66).jpg
# Dataset/train/without_mask/without_mask (39).jpg
# Dataset/train/without_mask/without_mask (151).jpg
# Dataset/train/without_mask/without_mask (159).jpg
# Dataset/train/without_mask/without_mask (74).jpg
# Dataset/train/without_mask/without_mask (180).jpg
# Dataset/train/without_mask/without_mask (21).jpg
# Dataset/train/without_mask/without_mask (105).jpg
# Dataset/train/without_mask/without_mask (133).jpg
# Dataset/train/without_mask/without_mask (196).jpg
# Dataset/train/without_mask/without_mask (132).jpg
# Dataset/train/without_mask/without_mask (163).jpg
# Dataset/train/without_mask/without_mask (12).jpg
# Dataset/train/without_mask/without_mask (15).jpg
# Dataset/train/without_mask/without_mask (120).jpg
# Dataset/train/without_mask/without_mask (205).jpg
# Dataset/train/without_mask/without_mask (104).jpg
# Dataset/train/without_mask/without_mask (25).jpg
# Dataset/train/without_mask/without_mask (83).jpg
# Dataset/train/without_mask/without_mask (154).jpg
# Dataset/train/without_mask/without_mask (173).jpg
# Dataset/train/without_mask/without_mask (134).jpg
# Dataset/train/without_mask/without_mask (117).jpg
# Dataset/train/without_mask/without_mask (22).jpg
# Dataset/train/without_mask/without_mask (170).jpg
# Dataset/train/without_mask/without_mask (165).jpg
# Dataset/train/without_mask/without_mask (181).jpg
# Dataset/train/without_mask/without_mask (157).jpg
# Dataset/train/without_mask/without_mask (63).jpg
# Dataset/train/without_mask/without_mask (210).jpg
# Dataset/train/without_mask/without_mask (87).jpg
# Dataset/train/without_mask/without_mask (141).jpg
# Dataset/train/without_mask/without_mask (138).jpg
# Dataset/train/without_mask/without_mask (56).jpg
# Dataset/train/without_mask/without_mask (126).jpg
# Dataset/train/without_mask/without_mask (208).jpg
# Dataset/train/without_mask/without_mask (198).jpg
# Dataset/train/without_mask/without_mask (187).jpg
# Dataset/train/without_mask/without_mask (190).jpg
# Dataset/train/without_mask/without_mask (209).jpg
# Dataset/train/without_mask/without_mask (38).jpg
# Dataset/train/without_mask/without_mask (94).jpg
# Dataset/train/without_mask/without_mask (93).jpg
# Dataset/train/without_mask/without_mask (113).jpg
# Dataset/train/without_mask/without_mask (49).jpg
# Dataset/train/without_mask/without_mask (116).jpg
# Dataset/train/without_mask/without_mask (59).jpg
# Dataset/train/without_mask/without_mask (62).jpg
# Dataset/train/without_mask/without_mask (70).jpg
# Dataset/train/without_mask/without_mask (101).jpg
# Dataset/train/without_mask/without_mask (167).jpg
# Dataset/train/without_mask/without_mask (84).jpg
# Dataset/train/without_mask/without_mask (50).jpg
# Dataset/train/without_mask/without_mask (197).jpg
# Dataset/train/without_mask/without_mask (174).jpg
# Dataset/train/without_mask/without_mask (200).jpg
# Dataset/train/without_mask/without_mask (9).jpg
# Dataset/train/without_mask/without_mask (90).jpg
# Dataset/train/without_mask/without_mask (122).jpg
# Dataset/train/without_mask/without_mask (195).jpg
# Dataset/train/without_mask/without_mask (171).jpg
# Dataset/train/without_mask/without_mask (145).jpg
# Dataset/train/without_mask/without_mask (82).jpg
# Dataset/train/without_mask/without_mask (11).jpg
# Dataset/train/without_mask/without_mask (81).jpg
# Dataset/train/without_mask/without_mask (127).jpg
# Dataset/train/without_mask/without_mask (14).jpg
# Dataset/train/without_mask/without_mask (69).jpg
# Dataset/train/without_mask/without_mask (123).jpg
# Dataset/train/without_mask/without_mask (142).jpg
# Dataset/train/without_mask/without_mask (54).jpg
# Dataset/train/without_mask/without_mask (111).jpg
# Dataset/train/without_mask/without_mask (121).jpg
# Dataset/train/without_mask/without_mask (177).jpg
# Dataset/train/without_mask/without_mask (183).jpg
# Dataset/train/without_mask/without_mask (61).jpg
# Dataset/train/without_mask/without_mask (194).jpg
# Dataset/train/without_mask/without_mask (172).jpg
# Dataset/train/without_mask/without_mask (130).jpg
# Dataset/train/without_mask/without_mask (146).jpg
# Dataset/train/without_mask/without_mask (53).jpg
# Dataset/train/without_mask/without_mask (189).jpg
# Dataset/train/without_mask/without_mask (168).jpg
# Dataset/train/without_mask/without_mask (65).jpg
# Dataset/train/without_mask/without_mask (192).jpg
# Dataset/train/without_mask/without_mask (78).jpg
# Dataset/train/without_mask/without_mask (3).jpg
# Dataset/train/without_mask/without_mask (166).jpg
# Dataset/train/without_mask/without_mask (114).jpg
# Dataset/train/without_mask/without_mask (185).jpg
# Dataset/train/without_mask/without_mask (35).jpg
# Dataset/train/without_mask/without_mask (106).jpg
# Dataset/train/without_mask/without_mask (204).jpg
# Dataset/train/without_mask/without_mask (136).jpg
# Dataset/train/without_mask/without_mask (176).jpg
# Dataset/train/without_mask/without_mask (184).jpg
# Dataset/train/without_mask/without_mask (164).jpg
# Dataset/train/without_mask/without_mask (203).jpg
# Dataset/train/without_mask/without_mask (175).jpg
# Dataset/train/without_mask/without_mask (150).jpg
# Dataset/train/without_mask/without_mask (155).jpg
# Dataset/train/without_mask/without_mask (45).jpg
# Dataset/train/without_mask/without_mask (58).jpg
# Dataset/train/without_mask/without_mask (125).jpg
# Dataset/train/without_mask/without_mask (51).jpg
# Dataset/train/without_mask/without_mask (80).jpg
# Dataset/train/without_mask/without_mask (32).jpg
# Dataset/train/without_mask/without_mask (43).jpg
# Dataset/train/without_mask/without_mask (55).jpg
# Dataset/train/without_mask/without_mask (67).jpg
# Dataset/train/without_mask/without_mask (206).jpg
# Dataset/train/without_mask/without_mask (2).jpg
# Dataset/train/without_mask/without_mask (26).jpg
# Dataset/train/without_mask/without_mask (85).jpg
# Dataset/train/without_mask/without_mask (86).jpg
# Dataset/train/without_mask/without_mask (149).jpg
# Dataset/train/without_mask/without_mask (169).jpg
# Dataset/train/without_mask/without_mask (158).jpg
# Dataset/train/without_mask/without_mask (64).jpg
# Dataset/train/without_mask/without_mask (191).jpg
# Dataset/train/without_mask/without_mask (129).jpg
# Dataset/train/without_mask/without_mask (193).jpg
# Dataset/train/without_mask/without_mask (124).jpg
# Dataset/train/without_mask/without_mask (71).jpg
# Dataset/train/without_mask/without_mask (199).jpg
# Dataset/train/without_mask/without_mask (1).jpg
# Dataset/train/without_mask/without_mask (135).jpg
# Dataset/train/without_mask/without_mask (148).jpg
# Dataset/train/without_mask/without_mask (161).jpg
# Dataset/train/without_mask/without_mask (10).jpg
# Dataset/train/without_mask/without_mask (96).jpg
# Dataset/train/without_mask/without_mask (27).jpg
# Dataset/train/without_mask/without_mask (156).jpg
# Dataset/train/without_mask/without_mask (37).jpg
# Dataset/train/without_mask/without_mask (115).jpg
# Dataset/train/without_mask/without_mask (29).jpg
# Dataset/train/without_mask/without_mask (47).jpg
# Dataset/train/without_mask/without_mask (103).jpg
# Dataset/train/without_mask/without_mask (4).jpg
# Dataset/train/without_mask/without_mask (99).jpg
# Dataset/train/without_mask/without_mask (188).jpg
# Dataset/train/without_mask/without_mask (118).jpg
# Dataset/train/without_mask/without_mask (52).jpg
# Dataset/train/without_mask/without_mask (46).jpg
# Dataset/train/without_mask/without_mask (77).jpg
# Dataset/train/without_mask/without_mask (95).jpg
# Dataset/train/without_mask/without_mask (144).jpg
# Dataset/train/without_mask/without_mask (41).jpg
# Dataset/train/without_mask/without_mask (110).jpg
# Dataset/train/without_mask/without_mask (162).jpg
# Dataset/train/without_mask/without_mask (30).jpg
# Dataset/train/without_mask/without_mask (202).jpg
# Dataset/train/without_mask/without_mask (109).jpg
# Dataset/train/without_mask/without_mask (178).jpg
# Dataset/train/without_mask/without_mask (76).jpg
# Dataset/train/without_mask/without_mask (7).jpg
# Dataset/train/without_mask/without_mask (179).jpg
# Dataset/train/without_mask/without_mask (16).jpg
# Dataset/train/without_mask/without_mask (20).jpg
# Dataset/train/without_mask/without_mask (98).jpg
# Dataset/train/without_mask/without_mask (72).jpg
# Dataset/train/without_mask/without_mask (201).jpg
# Dataset/train/without_mask/without_mask (31).jpg
# Dataset/train/without_mask/without_mask (60).jpg
# Dataset/train/without_mask/without_mask (17).jpg
# Dataset/train/without_mask/without_mask (73).jpg
# Dataset/train/without_mask/without_mask (128).jpg
# Dataset/train/without_mask/without_mask (42).jpg
# Dataset/train/without_mask/without_mask (92).jpg
# Dataset/train/without_mask/without_mask (88).jpg
# Dataset/train/without_mask/without_mask (91).jpg
# Dataset/train/without_mask/without_mask (139).jpg
# Dataset/train/without_mask/without_mask (18).jpg
# Dataset/train/without_mask/without_mask (40).jpg
# Dataset/train/without_mask/without_mask (36).jpg
# Dataset/train/without_mask/without_mask (48).jpg
# Dataset/train/without_mask/without_mask (137).jpg
# Dataset/train/without_mask/without_mask (160).jpg
# Dataset/train/without_mask/without_mask (13).jpg
# Dataset/train/without_mask/without_mask (102).jpg
# Dataset/train/without_mask/without_mask (143).jpg
# Dataset/train/without_mask/without_mask (107).jpg
# Dataset/train/without_mask/without_mask (24).jpg
# Dataset/train/without_mask/without_mask (44).jpg
# Dataset/train/without_mask/without_mask (182).jpg
# Dataset/train/without_mask/without_mask (153).jpg
# Dataset/train/without_mask/without_mask (119).jpg
# Dataset/train/without_mask/without_mask (131).jpg
# Dataset/train/without_mask/without_mask (152).jpg
# Dataset/train/without_mask/without_mask (33).jpg
# Dataset/train/without_mask/without_mask (100).jpg
# Dataset/train/without_mask/without_mask (57).jpg
# Dataset/train/without_mask/without_mask (6).jpg
# Dataset/train/without_mask/without_mask (23).jpg
# Dataset/train/without_mask/without_mask (34).jpg

# %%
test_img = []
test_label = [] 
for dir_path in glob.glob("Dataset/test/*"):
    label2 = dir_path.split("/")[-1]
    for img_path in glob.glob(os.path.join(dir_path, "*.jpg")):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        test_img.append(img)
        test_label.append(label2)
        
test_img = np.array(test_img)
test_label = np.array(test_label)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_label)
test_encoded = le.transform(test_label)
le.fit(train_label)
train_encoded = le.transform(train_label)

x_train, y_train, x_test, y_test = train_img, train_encoded, test_img, test_encoded

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
def feature_extractor(dataset):
    x_train = dataset
    img_dataset = pd.DataFrame()
    for image in range(x_train.shape[0]):
        
        df = pd.DataFrame()
        
        input_img = x_train[image, :,:,:]
        img = input_img
   
        # FEATURE 1 - Pixel values
        pixel_values = img.reshape(-1)
        df['Pixel_Value'] = pixel_values

        # FEATURE 2 Sobel
        edge_sobel = sobel(img)
        edge_sobel1 = edge_sobel.reshape(-1)
        df['Sobel'] = edge_sobel1

        img_dataset = img_dataset.append(df)
        
    return img_dataset

# %%
image_features = feature_extractor(x_train)

n_features = image_features.shape[1]
image_features = np.expand_dims(image_features, axis=0)
X_svm = np.reshape(image_features, (x_train.shape[0], -1)) 

from sklearn import svm
SVM_model = svm.SVC(decision_function_shape='ovo')
SVM_model.fit(X_svm, y_train)
# Out:
# SVC(decision_function_shape='ovo')

# %%
test_features = feature_extractor(x_test)
test_features = np.expand_dims(test_features, axis=0)
test_for_svm = np.reshape(test_features, (x_test.shape[0], -1))

test_prediction = SVM_model.predict(test_for_svm)

test_prediction = le.inverse_transform(test_prediction)

# %%
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_label, test_prediction))
# Out:
# Accuracy =  0.9539473684210527

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_label, test_prediction)

fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale=1.6)
sns.heatmap(cm, annot=True, ax=ax)
# Out:
# <AxesSubplot:>
